# %% [markdown]
# # Work-Life Firewall Kaggle Runner
#
# Run this notebook top-to-bottom in Kaggle with GPU enabled.
#
# ## Required Kaggle Secrets
# - `WANDB_API_KEY`
# - `HF_TOKEN` (optional, only needed for model upload)

# %%
import os
import shutil
import subprocess
from pathlib import Path

# Override via env vars if needed.
GITHUB_REPO = os.environ.get('GITHUB_REPO', 'https://github.com/EchoOfCode/meta_hackathon.git')
GITHUB_BRANCH = os.environ.get('GITHUB_BRANCH', 'main')
WORK_REPO_DIR = Path('/kaggle/working/meta_hackathon')
SAFE_CWD = Path('/kaggle/working')


def _run(cmd, cwd=None):
    run_cwd = str(cwd or SAFE_CWD)
    proc = subprocess.run(cmd, cwd=run_cwd, text=True, capture_output=True)
    if proc.returncode != 0:
        raise RuntimeError(
            f"Command failed: {' '.join(cmd)}\nSTDOUT:\n{proc.stdout}\nSTDERR:\n{proc.stderr}"
        )
    return proc


def _repo_url_with_token(repo_url: str) -> str:
    token = os.environ.get('GITHUB_TOKEN')
    if token and repo_url.startswith('https://github.com/'):
        return repo_url.replace('https://', f'https://{token}@', 1)
    return repo_url


def sync_repo_from_github() -> Path:
    """Always get latest branch tip into /kaggle/working/meta_hackathon."""
    repo_url = _repo_url_with_token(GITHUB_REPO)

    # Ensure we are never inside a path that may be deleted during sync.
    SAFE_CWD.mkdir(parents=True, exist_ok=True)
    os.chdir(SAFE_CWD)

    if (WORK_REPO_DIR / '.git').exists():
        _run(['git', 'fetch', 'origin', GITHUB_BRANCH], cwd=WORK_REPO_DIR)
        _run(['git', 'reset', '--hard', f'origin/{GITHUB_BRANCH}'], cwd=WORK_REPO_DIR)
    else:
        if WORK_REPO_DIR.exists():
            shutil.rmtree(WORK_REPO_DIR)
        _run([
            'git', 'clone', '--depth', '1', '--branch', GITHUB_BRANCH, repo_url, str(WORK_REPO_DIR)
        ], cwd=SAFE_CWD)

    return WORK_REPO_DIR


def find_repo_dir_from_inputs() -> Path:
    """Fallback for offline runs using attached Kaggle dataset input."""
    candidates = []

    working = Path('/kaggle/working')
    if working.exists():
        candidates.append(working)
        candidates.extend([p for p in working.iterdir() if p.is_dir()])

    input_root = Path('/kaggle/input')
    if input_root.exists():
        candidates.append(input_root)
        for ds in input_root.iterdir():
            if ds.is_dir():
                candidates.append(ds)
                candidates.extend([p for p in ds.iterdir() if p.is_dir()])

    for c in candidates:
        if (c / 'openenv.yaml').exists() and (c / 'training').exists():
            return c

    raise FileNotFoundError(
        'Could not find project root with openenv.yaml + training/. '
        'Attach dataset input or enable internet for GitHub sync.'
    )


# Default behavior: pull latest from GitHub each run.
USE_GITHUB_SYNC = os.environ.get('USE_GITHUB_SYNC', '1') == '1'

if USE_GITHUB_SYNC:
    try:
        REPO_DIR = sync_repo_from_github()
        print('Synced latest code from GitHub:', GITHUB_REPO, '@', GITHUB_BRANCH)
    except Exception as exc:
        print('GitHub sync failed, falling back to /kaggle/input snapshot:')
        print(exc)
        REPO_DIR = find_repo_dir_from_inputs()
else:
    REPO_DIR = find_repo_dir_from_inputs()

# /kaggle/input is read-only; copy to /kaggle/working for training outputs.
if str(REPO_DIR).startswith('/kaggle/input'):
    if WORK_REPO_DIR.exists() and WORK_REPO_DIR != REPO_DIR:
        shutil.rmtree(WORK_REPO_DIR)
    shutil.copytree(REPO_DIR, WORK_REPO_DIR, dirs_exist_ok=True)
    REPO_DIR = WORK_REPO_DIR

os.chdir(REPO_DIR)
print('CWD:', Path.cwd())
print('Using project root:', REPO_DIR)
# !python --version
# !nvidia-smi
# Out:
# Synced latest code from GitHub: https://github.com/EchoOfCode/meta_hackathon.git @ main
# CWD: /kaggle/working/meta_hackathon
# Using project root: /kaggle/working/meta_hackathon
# Python 3.12.12
# Sun Apr 26 05:17:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -r requirements.txt
# !pip install -q openenv trl==0.23.1 unsloth bitsandbytes huggingface_hub
# Out:
# Collecting openenv (from -r requirements.txt (line 3))
#   Downloading openenv-0.1.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: datasets>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.8.3)
# Collecting transformers==4.57.2 (from -r requirements.txt (line 10))
#   Downloading transformers-4.57.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.8 MB/s eta 0:00:00
# Collecting trl==0.23.1 (from -r requirements.txt (line 11))
#   Downloading trl-0.23.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.18.1)
# Collecting bitsandbytes>=0.43.0 (from -r requirements.txt (line 13))
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (1.12.0)
# Collecting mergekit>=0.1.4 (from -r requirements.txt (line 15))
#   Downloading mergekit-0.1.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.4.1)
# Requirement already satisfied: wandb>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (0.25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (3.24.3)
# Collecting huggingface_hub>=0.34.0 (from -r requirements.txt (line 16))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2026.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0->-r requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0->-r requirements.txt (line 12)) (2.10.0+cu128)
# Collecting tqdm>=4.27 (from transformers==4.57.2->-r requirements.txt (line 10))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.6 MB/s eta 0:00:00
# Collecting click==8.2.1 (from mergekit>=0.1.4->-r requirements.txt (line 15))
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting safetensors>=0.4.3 (from transformers==4.57.2->-r requirements.txt (line 10))
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting accelerate>=0.34.0 (from -r requirements.txt (line 14))
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting pydantic~=2.10.6 (from mergekit>=0.1.4->-r requirements.txt (line 15))
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting immutables==0.21 (from mergekit>=0.1.4->-r requirements.txt (line 15))
#   Downloading immutables-0.21-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (5.29.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (4.9.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (2.53.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.17.0->-r requirements.txt (line 19)) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.10.6->mergekit>=0.1.4->-r requirements.txt (line 15)) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic~=2.10.6->mergekit>=0.1.4->-r requirements.txt (line 15))
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.2->-r requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.2->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.17.0->-r requirements.txt (line 19)) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.0.3)
# Downloading transformers-4.57.2-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 103.3 MB/s eta 0:00:00
# Downloading trl-0.23.1-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.6/564.6 kB 36.3 MB/s eta 0:00:00
# Downloading openenv-0.1.13-py3-none-any.whl (12 kB)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.3 MB/s eta 0:00:00
# Downloading mergekit-0.1.4-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.5 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 6.9 MB/s eta 0:00:00
# Downloading immutables-0.21-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 8.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.0 MB/s eta 0:00:00
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 25.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 35.1 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 30.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.4 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 29.6 MB/s eta 0:00:00
# Installing collected packages: tqdm, safetensors, pydantic-core, openenv, immutables, click, pydantic, huggingface_hub, transformers, bitsandbytes, accelerate, trl, mergekit
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# a2a-sdk 0.3.25 requires pydantic>=2.11.3, but you have pydantic 2.10.6 which is incompatible.
# kaggle-environments 1.27.3 requires pydantic>=2.11.4, but you have pydantic 2.10.6 which is incompatible.
# sigstore-models 0.0.6 requires pydantic>=2.12, but you have pydantic 2.10.6 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# mcp 1.26.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 2.10.6 which is incompatible.
# rasterio 1.5.0 requires click!=8.2.*,>=4.0, but you have click 8.2.1 which is incompatible.
# Successfully installed accelerate-1.6.0 bitsandbytes-0.49.2 click-8.2.1 huggingface_hub-0.36.2 immutables-0.21 mergekit-0.1.4 openenv-0.1.13 pydantic-2.10.6 pydantic-core-2.27.2 safetensors-0.5.3 tqdm-4.67.1 transformers-4.57.2 trl-0.23.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 101.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 99.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 88.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 17.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# kaggle-environments 1.27.3 requires pydantic>=2.11.4, but you have pydantic 2.10.6 which is incompatible.
# s3fs 2026.2.0 requires fsspec==2026.2.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.

# %%
import os
from kaggle_secrets import UserSecretsClient

secrets = UserSecretsClient()

# WandB token (required for tracking)
os.environ['WANDB_API_KEY'] = secrets.get_secret('WANDB_API_KEY')
os.environ['WANDB_PROJECT'] = 'meta_hackathon'

# HF token is optional; needed only if you push model from Kaggle
try:
    os.environ['HF_TOKEN'] = secrets.get_secret('HF_TOKEN')
    os.environ['HUGGINGFACE_HUB_TOKEN'] = os.environ['HF_TOKEN']
    print('HF token loaded from Kaggle Secrets')
except Exception:
    print('HF token not set (this is okay if you are not uploading model now)')

print('WandB key loaded:', bool(os.environ.get('WANDB_API_KEY')))
# Out:
# HF token loaded from Kaggle Secrets
# WandB key loaded: True

# %%
# Fast stable run for Kaggle T4
# !python training/train.py --mode real --speed-preset fast --size-preset medium --steps 300 --run-name meta-kaggle-final --wandb-project meta_hackathon
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# 2026-04-26 05:18:05.946318: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777180686.124481      93 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777180686.181291      93 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777180686.639207      93 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777180686.639312      93 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777180686.639328      93 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777180686.639340      93 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# config.json: 100%|█████████████████████████████| 660/660 [00:00<00:00, 4.57MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:  46%|█████████▏          | 1.41G/3.09G [00:14<00:16, 101MB/s]
# generation_config.json: 100%|██████████████████| 242/242 [00:00<00:00, 1.74MB/s]
# tokenizer_config.json: 7.30kB [00:00, 4.20MB/s]
# vocab.json: 2.78MB [00:00, 50.8MB/s]
# merges.txt: 1.67MB [00:00, 135MB/s]
# tokenizer.json: 7.03MB [00:00, 102MB/s]
# Trainable params: 18,464,768 / 907,081,216 (2.04%)
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: yusufindian09 (yusufindian09-aaa) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/meta_hackathon/wandb/run-20260426_051854-6oai3cqg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run meta-kaggle-final
# wandb: ⭐️ View project at https://wandb.ai/yusufindian09-aaa/meta_hackathon
# wandb: 🚀 View run at https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/6oai3cqg
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 1
0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.42000000476837157, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.42000000476837157, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.6536458492279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.52}
# {'loss': 0.0, 'grad_norm': 0.5596994757652283, 'learning_rate': 9.066666666666667e-06, 'num_tokens': 65946.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.44000000357627866, 'rewards/reward_funcs/std': 0.08485280871391296, 'reward': 0.44000000357627866, 'reward_std': 0.08485280871391296, 'frac_reward_zero_std': 0.6, 'entropy': 2.4270833492279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.57}
# {'loss': 0.0, 'grad_norm': 0.6069872975349426, 'learning_rate': 8.733333333333333e-06, 'num_tokens': 67930.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.3800000071525574, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.5783854484558106, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.62}
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 8.400000000000001e-06, 'num_tokens': 69958.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.34000000953674314, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.34000000953674314, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.691666674613953, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.67}
# {'loss': 0.0, 'grad_norm': 0.5118393898010254, 'learning_rate': 8.066666666666667e-06, 'num_tokens': 71954.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.34000000953674314, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.34000000953674314, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.8, 'entropy': 2.4705729246139527, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.71}
# {'loss': 0.0, 'grad_norm': 0.5966246724128723, 'learning_rate': 7.733333333333334e-06, 'num_tokens': 73946.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3600000083446503, 'rewards/reward_funcs/std': 0.08485280871391296, 'reward': 0.3600000083446503, 'reward_std': 0.08485280871391296, 'frac_reward_zero_std': 0.4, 'entropy': 2.4033854961395265, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.76}
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 7.4e-06, 'num_tokens': 75956.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.0, 'reward': 0.3800000071525574, 'reward_std': 0.0, 'frac_reward_zero_std': 1.0, 'entropy': 2.6653645515441893, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.81}
# {'loss': 0.0, 'grad_norm': 0.6225645542144775, 'learning_rate': 7.066666666666667e-06, 'num_tokens': 77932.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.3800000071525574, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.2817708015441895, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.86}
# {'loss': 0.0, 'grad_norm': 0.6114572882652283, 'learning_rate': 6.733333333333334e-06, 'num_tokens': 79918.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.4000000059604645, 'rewards/reward_funcs/std': 0.08485280871391296, 'reward': 0.4000000059604645, 'reward_std': 0.08485280871391296, 'frac_reward_zero_std': 0.4, 'entropy': 2.4815104484558104, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.9}
# {'loss': 0.0, 'grad_norm': 0.5556877255439758, 'learning_rate': 6.4000000000000006e-06, 'num_tokens': 81936.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.42000000476837157, 'rewards/reward_funcs/std': 0.16970561742782592, 'reward': 0.42000000476837157, 'reward_std': 0.16970561742782592, 'frac_reward_zero_std': 0.2, 'entropy': 2.262499976158142, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch':
0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3600000083446503, 'rewards/reward_funcs/std': 0.02828426957130432, 'reward': 0.3600000083446503, 'reward_std': 0.02828426957130432, 'frac_reward_zero_std': 0.8, 'entropy': 2.3122395992279055, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.48}
# {'loss': 0.0, 'grad_norm': 0.6132684946060181, 'learning_rate': 2.4000000000000003e-06, 'num_tokens': 105928.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.4000000059604645, 'rewards/reward_funcs/std': 0.1414213478565216, 'reward': 0.4000000059604645, 'reward_std': 0.1414213478565216, 'frac_reward_zero_std': 0.2, 'entropy': 2.765885353088379, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.52}
# {'loss': 0.0, 'grad_norm': 0.5847970843315125, 'learning_rate': 2.0666666666666666e-06, 'num_tokens': 107920.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.4000000059604645, 'rewards/reward_funcs/std': 0.08485280871391296, 'reward': 0.4000000059604645, 'reward_std': 0.08485280871391296, 'frac_reward_zero_std': 0.4, 'entropy': 2.6263020992279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.57}
# {'loss': 0.0, 'grad_norm': 0.5431052446365356, 'learning_rate': 1.7333333333333336e-06, 'num_tokens': 109908.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.40000001192092893, 'rewards/reward_funcs/std': 0.08485280871391296, 'reward': 0.40000001192092893, 'reward_std': 0.08485280871391296, 'frac_reward_zero_std': 0.4, 'entropy': 2.46875, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.62}
# {'loss': 0.0, 'grad_norm': 0.6762590408325195, 'learning_rate': 1.4000000000000001e-06, 'num_tokens': 111904.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.11313707828521728, 'reward': 0.3800000071525574, 'reward_std': 0.11313707828521728, 'frac_reward_zero_std': 0.2, 'entropy': 2.5963541507720946, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.67}
# {'loss': 0.0, 'grad_norm': 0.5363702178001404, 'learning_rate': 1.066666666666667e-06, 'num_tokens': 113900.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.3800000071525574, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.678906202316284, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.71}
# {'loss': 0.0, 'grad_norm': 0.6141514182090759, 'learning_rate': 7.333333333333334e-07, 'num_tokens': 115902.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.11313707828521728, 'reward': 0.3800000071525574, 'reward_std': 0.11313707828521728, 'frac_reward_zero_std': 0.2, 'entropy': 2.3145833015441895, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.76}
# {'loss': 0.0, 'grad_norm': 0.5981648564338684, 'learning_rate': 4.0000000000000003e-07, 'num_tokens': 117890.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.42000000476837157, 'rewards/reward_funcs/std': 0.05656853914260864, 'reward': 0.42000000476837157, 'reward_std': 0.05656853914260864, 'frac_reward_zero_std': 0.6, 'entropy': 2.485156226158142, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.81}
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 6.666666666666668e-08, 'num_tokens': 119914.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.3800000071525574, 'rewards/reward_funcs/std': 0.11313707828521728, 'reward': 0.3800000071525574, 'reward_std': 0.11313707828521728, 'frac_reward_zero_std': 0.2, 'entropy': 2.5755208492279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.86}
# {'train_runtime': 3443.4112, 'train_samples_per_second': 0.174, 'train_steps_per_second': 0.087, 'train_loss': 1.3907750447591146e-09, 'epoch': 2.86}
# 100%|█████████████████████████████████████████| 300/300 [57:20<00:00, 11.47s/it]
# Saved metrics → evaluation/results/training_metrics.json
# Real training complete → checkpoints/final
# wandb:
# wandb: 🚀 View run meta-kaggle-final at: https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/6oai3cqg
# wandb: Find logs at: wandb/run-20260426_051854-6oai3cqg/logs

# %%
import json
from pathlib import Path

metrics_path = Path('evaluation/results/training_metrics.json')
metrics = json.loads(metrics_path.read_text())
print('Metrics file:', metrics_path)
print('Mode:', metrics.get('mode'))
print('Model:', metrics.get('model_id'))
print('Train runtime (s):', metrics.get('train_runtime_seconds'))
print('WandB URL:', metrics.get('wandb_run_url'))
print('Loss points:', len(metrics.get('loss_curve', [])))
print('Reward points:', len(metrics.get('reward_curve', [])))
# Out:
# Metrics file: evaluation/results/training_metrics.json
# Mode: real
# Model: Qwen/Qwen2.5-1.5B-Instruct
# Train runtime (s): 3443.4112
# WandB URL: https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/6oai3cqg
# Loss points: 60
# Reward points: 60

# %%
#!python evaluation/evaluate.py --episodes 50
# !python evaluation/plot_results.py
# !ls -lah evaluation/results
# Out:
# Saved PNG plots in evaluation/results/
# total 1.1M
# drwxr-xr-x 2 root root 4.0K Apr 26 05:17 .
# drwxr-xr-x 4 root root 4.0K Apr 26 05:17 ..
# -rw-r--r-- 1 root root  34K Apr 26 06:16 component_breakdown.png
# -rw-r--r-- 1 root root  51K Apr 26 06:16 decision_heatmap.png
# -rw-r--r-- 1 root root  22K Apr 26 06:16 energy_trajectory.png
# -rw-r--r-- 1 root root 6.9K Apr 26 05:17 evaluation_summary.json
# -rw-r--r-- 1 root root  14K Apr 26 06:16 loss_curve.png
# -rw-r--r-- 1 root root 466K Apr 26 05:17 profiling_20260426.png
# -rw-r--r-- 1 root root  44K Apr 26 06:16 reward_curve.png
# -rw-r--r-- 1 root root 348K Apr 26 05:17 train_20260426.png
# -rw-r--r-- 1 root root  57K Apr 26 06:16 training_metrics.json

# %%
# Package submission artifacts for download
# !zip -r submission_artifacts.zip README.md openenv.yaml environment training evaluation/results -x "*/__pycache__/*" "*.pyc" ".ipynb_checkpoints/*"
# !ls -lah submission_artifacts.zip
# Out:
#   adding: README.md (deflated 63%)
#   adding: openenv.yaml (deflated 29%)
#   adding: environment/ (stored 0%)
#   adding: environment/judge.py (deflated 55%)
#   adding: environment/__init__.py (deflated 23%)
#   adding: environment/reward.py (deflated 67%)
#   adding: environment/env.py (deflated 64%)
#   adding: environment/state.py (deflated 66%)
#   adding: environment/events.py (deflated 74%)
#   adding: environment/consequences.py (deflated 65%)
#   adding: training/ (stored 0%)
#   adding: training/train.ipynb (deflated 70%)
#   adding: training/train.py (deflated 70%)
#   adding: training/__init__.py (stored 0%)
#   adding: training/rollout.py (deflated 50%)
#   adding: training/grpo_config.py (deflated 43%)
#   adding: training/push_to_hf.py (deflated 50%)
#   adding: evaluation/results/ (stored 0%)
#   adding: evaluation/results/train_20260426.png (deflated 6%)
#   adding: evaluation/results/reward_curve.png (deflated 5%)
#   adding: evaluation/results/energy_trajectory.png (deflated 12%)
#   adding: evaluation/results/loss_curve.png (deflated 21%)
#   adding: evaluation/results/training_metrics.json (deflated 94%)
#   adding: evaluation/results/evaluation_summary.json (deflated 81%)
#   adding: evaluation/results/decision_heatmap.png (deflated 12%)
#   adding: evaluation/results/profiling_20260426.png (deflated 3%)
#   adding: evaluation/results/component_breakdown.png (deflated 15%)
# -rw-r--r-- 1 root root 952K Apr 26 06:16 submission_artifacts.zip

# %%
# Optional: upload model to HF Model Hub
# Uncomment and edit repo id when needed
# !python training/push_to_hf.py --repo-id YUS200619/meta_hackathon-qwen-model --folder checkpoints/final
# Out:
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   0%|              | 45.7kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  13%|█▉            | 11.5MB / 85.3MB, 57.2MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   0%|              | 45.7kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  14%|█▉            | 12.0MB / 85.3MB, 20.0MB/s
# New Data Upload               :   1%|              |  557kB / 73.9MB,  929kB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  33%|████▌         | 28.2MB / 85.3MB, 35.2MB/s
# New Data Upload               :  23%|███▏          | 16.7MB / 73.9MB, 20.9MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  70%|█████████▋    | 59.4MB / 85.3MB, 59.4MB/s
# New Data Upload               :  65%|█████████     | 47.9MB / 73.9MB, 47.9MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  92%|████████████▊ | 78.4MB / 85.3MB, 65.3MB/s
# New Data Upload               :  91%|████████████▋ | 66.9MB / 73.9MB, 55.7MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 66.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 66.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 66.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      : 100%|█████████████▉| 85.3MB / 85.3MB, 42.6MB/s
# New Data Upload               : 100%|█████████████▉| 73.8MB / 73.9MB, 36.9MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 85.3MB / 85.3MB, 38.8MB/s
# New Data Upload               : 100%|██████████████| 73.9MB / 73.9MB, 33.6MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 73.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 73.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 85.3MB / 85.3MB, 32.8MB/s
# New Data Upload               : 100%|██████████████| 73.9MB / 73.9MB, 28.4MB/s
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#   ...adapter_model.safetensors: 100%|██████████████| 73.9MB / 73.9MB
# Uploaded model folder to https://huggingface.co/YUS200619/meta_hackathon-qwen-model
