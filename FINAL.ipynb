# %% [markdown]
# # Work-Life Firewall Kaggle Runner
#
# Run this notebook top-to-bottom in Kaggle with GPU enabled.
#
# ## Required Kaggle Secrets
# - `WANDB_API_KEY`
# - `HF_TOKEN` (optional, only needed for model upload)

# %%
import os
import shutil
import subprocess
from pathlib import Path

# Override via env vars if needed.
GITHUB_REPO = os.environ.get('GITHUB_REPO', 'https://github.com/EchoOfCode/meta_hackathon.git')
GITHUB_BRANCH = os.environ.get('GITHUB_BRANCH', 'main')
WORK_REPO_DIR = Path('/kaggle/working/meta_hackathon')
SAFE_CWD = Path('/kaggle/working')


def _run(cmd, cwd=None):
    run_cwd = str(cwd or SAFE_CWD)
    proc = subprocess.run(cmd, cwd=run_cwd, text=True, capture_output=True)
    if proc.returncode != 0:
        raise RuntimeError(
            f"Command failed: {' '.join(cmd)}\nSTDOUT:\n{proc.stdout}\nSTDERR:\n{proc.stderr}"
        )
    return proc


def _repo_url_with_token(repo_url: str) -> str:
    token = os.environ.get('GITHUB_TOKEN')
    if token and repo_url.startswith('https://github.com/'):
        return repo_url.replace('https://', f'https://{token}@', 1)
    return repo_url


def sync_repo_from_github() -> Path:
    """Always get latest branch tip into /kaggle/working/meta_hackathon."""
    repo_url = _repo_url_with_token(GITHUB_REPO)

    # Ensure we are never inside a path that may be deleted during sync.
    SAFE_CWD.mkdir(parents=True, exist_ok=True)
    os.chdir(SAFE_CWD)

    if (WORK_REPO_DIR / '.git').exists():
        _run(['git', 'fetch', 'origin', GITHUB_BRANCH], cwd=WORK_REPO_DIR)
        _run(['git', 'reset', '--hard', f'origin/{GITHUB_BRANCH}'], cwd=WORK_REPO_DIR)
    else:
        if WORK_REPO_DIR.exists():
            shutil.rmtree(WORK_REPO_DIR)
        _run([
            'git', 'clone', '--depth', '1', '--branch', GITHUB_BRANCH, repo_url, str(WORK_REPO_DIR)
        ], cwd=SAFE_CWD)

    return WORK_REPO_DIR


def find_repo_dir_from_inputs() -> Path:
    """Fallback for offline runs using attached Kaggle dataset input."""
    candidates = []

    working = Path('/kaggle/working')
    if working.exists():
        candidates.append(working)
        candidates.extend([p for p in working.iterdir() if p.is_dir()])

    input_root = Path('/kaggle/input')
    if input_root.exists():
        candidates.append(input_root)
        for ds in input_root.iterdir():
            if ds.is_dir():
                candidates.append(ds)
                candidates.extend([p for p in ds.iterdir() if p.is_dir()])

    for c in candidates:
        if (c / 'openenv.yaml').exists() and (c / 'training').exists():
            return c

    raise FileNotFoundError(
        'Could not find project root with openenv.yaml + training/. '
        'Attach dataset input or enable internet for GitHub sync.'
    )


# Default behavior: pull latest from GitHub each run.
USE_GITHUB_SYNC = os.environ.get('USE_GITHUB_SYNC', '1') == '1'

if USE_GITHUB_SYNC:
    try:
        REPO_DIR = sync_repo_from_github()
        print('Synced latest code from GitHub:', GITHUB_REPO, '@', GITHUB_BRANCH)
    except Exception as exc:
        print('GitHub sync failed, falling back to /kaggle/input snapshot:')
        print(exc)
        REPO_DIR = find_repo_dir_from_inputs()
else:
    REPO_DIR = find_repo_dir_from_inputs()

# /kaggle/input is read-only; copy to /kaggle/working for training outputs.
if str(REPO_DIR).startswith('/kaggle/input'):
    if WORK_REPO_DIR.exists() and WORK_REPO_DIR != REPO_DIR:
        shutil.rmtree(WORK_REPO_DIR)
    shutil.copytree(REPO_DIR, WORK_REPO_DIR, dirs_exist_ok=True)
    REPO_DIR = WORK_REPO_DIR

os.chdir(REPO_DIR)
print('CWD:', Path.cwd())
print('Using project root:', REPO_DIR)
# !python --version
# !nvidia-smi
# Out:
# Synced latest code from GitHub: https://github.com/EchoOfCode/meta_hackathon.git @ main
# CWD: /kaggle/working/meta_hackathon
# Using project root: /kaggle/working/meta_hackathon
# Python 3.12.12
# Sun Apr 26 07:31:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -r requirements.txt
# !pip install -q openenv trl==0.23.1 unsloth bitsandbytes huggingface_hub
# Out:
# Requirement already satisfied: openenv in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.1.13)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: datasets>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.3.0)
# Requirement already satisfied: transformers==4.57.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (4.57.2)
# Requirement already satisfied: trl==0.23.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.23.1)
# Requirement already satisfied: peft>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: bitsandbytes>=0.43.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.49.2)
# Requirement already satisfied: accelerate>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (1.6.0)
# Requirement already satisfied: mergekit>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (0.1.4)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (0.36.2)
# Requirement already satisfied: wandb>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (0.25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (3.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.2->-r requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 5)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.20.0->-r requirements.txt (line 9)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2025.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0->-r requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0->-r requirements.txt (line 12)) (2.10.0+cu128)
# Requirement already satisfied: click==8.2.1 in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (8.2.1)
# Requirement already satisfied: pydantic~=2.10.6 in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (2.10.6)
# Requirement already satisfied: immutables==0.21 in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (0.21)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (5.29.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mergekit>=0.1.4->-r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (4.9.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.0->-r requirements.txt (line 19)) (2.53.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (3.13.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.17.0->-r requirements.txt (line 19)) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.20.0->-r requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.10.6->mergekit>=0.1.4->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.10.6->mergekit>=0.1.4->-r requirements.txt (line 15)) (2.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.2->-r requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.2->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets>=2.20.0->-r requirements.txt (line 9)) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.17.0->-r requirements.txt (line 19)) (5.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft>=0.12.0->-r requirements.txt (line 12)) (3.0.3)

# %%
import os
from kaggle_secrets import UserSecretsClient

secrets = UserSecretsClient()

# WandB token (required for tracking)
os.environ['WANDB_API_KEY'] = secrets.get_secret('WANDB_API_KEY')
os.environ['WANDB_PROJECT'] = 'meta_hackathon'

# HF token is optional; needed only if you push model from Kaggle
try:
    os.environ['HF_TOKEN'] = secrets.get_secret('HF_TOKEN')
    os.environ['HUGGINGFACE_HUB_TOKEN'] = os.environ['HF_TOKEN']
    print('HF token loaded from Kaggle Secrets')
except Exception:
    print('HF token not set (this is okay if you are not uploading model now)')

print('WandB key loaded:', bool(os.environ.get('WANDB_API_KEY')))
# Out:
# HF token loaded from Kaggle Secrets
# WandB key loaded: True

# %%
# Fast stable run for Kaggle T4
# !python training/train.py --mode real --speed-preset fast --size-preset medium --steps 300 --run-name final-better-reward --wandb-project meta_hackathon
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# 2026-04-26 07:31:44.383609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777188704.407220    1664 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777188704.414994    1664 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777188704.434599    1664 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777188704.434626    1664 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777188704.434629    1664 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777188704.434633    1664 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Trainable params: 18,464,768 / 907,081,216 (2.04%)
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: yusufindian09 (yusufindian09-aaa) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run cccimx7s (0.3s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /kaggle/working/meta_hackathon/wandb/run-20260426_073200-cccimx7s
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run final-better-reward
# wandb: ⭐️ View project at https://wandb.ai/yusufindian09-aaa/meta_hackathon
# wandb: 🚀 View run at https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/cccimx7s
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# {'loss': 0.0, 'grad_norm': 0.5240530967712402, 'learning_rate': 1.9733333333333336e-05, 'num_tokens': 2002.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9555000066757202, 'rewards/reward_funcs/std': 0.032668334618210795, 'reward': 0.9555000066757202, 'reward_std': 0.032668334618210795, 'frac_reward_zero_std': 0.4, 'entropy': 2.580468702316284, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 0.05}
# {'loss': 0.0, 'grad_norm': 0.4835105240345001, 'learning_rate': 1.94e-05, 'num_tokens': 4000.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9718000054359436, 'rewards/reward_funcs/std': 0.031206968799233438, 'reward': 0.9718000054359436, 'reward_std': 0.031206968799233438, 'frac_reward_zero_std': 0.2, 'entropy': 2.44609375, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 0
0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9809333324432373, 'rewards/reward_funcs/std': 0.01527350377291441, 'reward': 0.9809333324432373, 'reward_std': 0.01527350377291441, 'frac_reward_zero_std': 0.4, 'entropy': 2.5690104007720946, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.48}
# {'loss': -0.0, 'grad_norm': 0.0, 'learning_rate': 9.4e-06, 'num_tokens': 63950.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9429000020027161, 'rewards/reward_funcs/std': 0.023994487896561622, 'reward': 0.9429000020027161, 'reward_std': 0.023994487896561622, 'frac_reward_zero_std': 0.4, 'entropy': 2.6825520992279053, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.52}
# {'loss': -0.0, 'grad_norm': 0.5552587509155273, 'learning_rate': 9.066666666666667e-06, 'num_tokens': 65946.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9565666675567627, 'rewards/reward_funcs/std': 0.057652765139937404, 'reward': 0.9565666675567627, 'reward_std': 0.057652765139937404, 'frac_reward_zero_std': 0.2, 'entropy': 2.477083349227905, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.57}
# {'loss': -0.0, 'grad_norm': 0.5159528255462646, 'learning_rate': 8.733333333333333e-06, 'num_tokens': 67930.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9872666597366333, 'rewards/reward_funcs/std': 0.014236421696841717, 'reward': 0.9872666597366333, 'reward_std': 0.014236421696841717, 'frac_reward_zero_std': 0.2, 'entropy': 2.305208349227905, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.62}
# {'loss': -0.0, 'grad_norm': 0.5623486638069153, 'learning_rate': 8.400000000000001e-06, 'num_tokens': 69958.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9637666583061218, 'rewards/reward_funcs/std': 0.048790363734588026, 'reward': 0.9637666583061218, 'reward_std': 0.048790363734588026, 'frac_reward_zero_std': 0.4, 'entropy': 2.4794270992279053, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.67}
# {'loss': -0.0, 'grad_norm': 0.59669029712677, 'learning_rate': 8.066666666666667e-06, 'num_tokens': 71954.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9786999940872192, 'rewards/reward_funcs/std': 0.027671445906162263, 'reward': 0.9786999940872192, 'reward_std': 0.027671445906162263, 'frac_reward_zero_std': 0.4, 'entropy': 2.5872395515441893, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.71}
# {'loss': 0.0, 'grad_norm': 0.5921006798744202, 'learning_rate': 7.733333333333334e-06, 'num_tokens': 73946.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9536333322525025, 'rewards/reward_funcs/std': 0.02456018254160881, 'reward': 0.9536333322525025, 'reward_std': 0.02456018254160881, 'frac_reward_zero_std': 0.4, 'entropy': 2.650520849227905, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.76}
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 7.4e-06, 'num_tokens': 75956.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9822666645050049, 'rewards/reward_funcs/std': 0.02130749076604843, 'reward': 0.9822666645050049, 'reward_std': 0.02130749076604843, 'frac_reward_zero_std': 0.6, 'entropy': 2.5765625, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.81}
# {'loss': -0.0, 'grad_norm': 0.0, 'learning_rate': 7.066666666666667e-06, 'num_tokens': 77932.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9839333295822144, 'rewards/reward_funcs/std': 0.01103086695075035, 'reward': 0.9839333295822144, 'reward_std': 0.01103086695075035, 'frac_reward_zero_std': 0.4, 'entropy': 2.476041650772095, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.86}
# {'loss': -0.0, 'grad_norm': 0.5653746724128723, 'learning_rate': 6.733333333333334e-06, 'num_tokens': 79918.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9720999956130981, 'rewards/reward_funcs/std': 0.02531441692262888, 'reward': 0.9720999956130981, 'reward_std': 0.02531441692262888, 'frac_reward_zero_std': 0.2, 'entropy': 2.3989583015441895, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.9}
# {'loss': -0.0, 'grad_norm': 0.5881668925285339, 'learning_rate': 6.4000000000000006e-06, 'num_tokens': 81936.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9556999921798706, 'rewards/reward_funcs/std': 0.045867662969976665, 'reward': 0.9556999921798706, 'reward_std': 0.045867662969976665, 'frac_reward_zero_std': 0.4, 'entropy': 2.5713541507720947, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 1.95}
# {'loss': 0.0, 'grad_norm': 0.5882717370986938, 'learning_rate': 6.066666666666667e-06, 'num_tokens': 83936.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9588666677474975, 'rewards/reward_funcs/std': 0.058171314746141435, 'reward': 0.9588666677474975, 'reward_std': 0.058171314746141435, 'frac_reward_zero_std': 0.2, 'entropy': 2.5052083492279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.0}
# {'loss': 0.0, 'grad_norm': 0.0, 'learning_rate': 5.733333333333334e-06, 'num_tokens': 85944.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9891666650772095, 'rewards/reward_funcs/std': 0.015320648998022079, 'reward': 0.9891666650772095, 'reward_std': 0.015320648998022079, 'frac_reward_zero_std': 0.6, 'entropy': 2.7356770992279054, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.05}
# {'loss': -0.0, 'grad_norm': 0.5583775639533997, 'learning_rate': 5.400000000000001e-06, 'num_tokens': 87964.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9579333186149597, 'rewards/reward_funcs/std': 0.05949125969782472, 'reward': 0.9579333186149597, 'reward_std': 0.05949125969782472, 'frac_reward_zero_std': 0.2, 'entropy': 2.6546875, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.1}
# {'loss': 0.0, 'grad_norm': 0.5689942240715027, 'learning_rate': 5.0666666666666676e-06, 'num_tokens': 89972.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9639000058174133, 'rewards/reward_funcs/std': 0.030217031389474867, 'reward': 0.9639000058174133, 'reward_std': 0.030217031389474867, 'frac_reward_zero_std': 0.2, 'entropy': 2.6606770515441895, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.14}
# {'loss': 0.0, 'grad_norm': 0.5988953113555908, 'learning_rate': 4.7333333333333335e-06, 'num_tokens': 91984.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9690666675567627, 'rewards/reward_funcs/std': 0.03752379454672337, 'reward': 0.9690666675567627, 'reward_std': 0.03752379454672337, 'frac_reward_zero_std': 0.2, 'entropy': 2.4364583015441896, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.19}
# {'loss': -0.0, 'grad_norm': 0.5035400390625, 'learning_rate': 4.4e-06, 'num_tokens': 93982.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.982099997997284, 'rewards/reward_funcs/std': 0.01946900337934494, 'reward': 0.982099997997284, 'reward_std': 0.01946900337934494, 'frac_reward_zero_std': 0.2, 'entropy': 2.41796875, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.24}
# {'loss': -0.0, 'grad_norm': 0.58883136510849, 'learning_rate': 4.066666666666667e-06, 'num_tokens': 95968.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9291666746139526, 'rewards/reward_funcs/std': 0.10017345361411571, 'reward': 0.9291666746139526, 'reward_std': 0.10017344765365124, 'frac_reward_zero_std': 0.2, 'entropy': 2.508333349227905, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.29}
# {'loss': -0.0, 'grad_norm': 0.6071673035621643, 'learning_rate': 3.7333333333333337e-06, 'num_tokens': 97950.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.943066668510437, 'rewards/reward_funcs/std': 0.052420183643698694, 'reward': 0.943066668510437, 'reward_std': 0.052420183643698694, 'frac_reward_zero_std': 0.2, 'entropy': 2.4156249523162843, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2
 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.76}
# {'loss': -0.0, 'grad_norm': 0.6778834462165833, 'learning_rate': 4.0000000000000003e-07, 'num_tokens': 117890.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.973199999332428, 'rewards/reward_funcs/std': 0.034129684884101154, 'reward': 0.973199999332428, 'reward_std': 0.03412968339398503, 'frac_reward_zero_std': 0.2, 'entropy': 2.397656273841858, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.81}
# {'loss': 0.0, 'grad_norm': 0.5681074261665344, 'learning_rate': 6.666666666666668e-08, 'num_tokens': 119914.0, 'completions/mean_length': 96.0, 'completions/min_length': 96.0, 'completions/max_length': 96.0, 'completions/clipped_ratio': 1.0, 'completions/mean_terminated_length': 0.0, 'completions/min_terminated_length': 0.0, 'completions/max_terminated_length': 0.0, 'rewards/reward_funcs/mean': 0.9860333442687989, 'rewards/reward_funcs/std': 0.011360843479633332, 'reward': 0.9860333442687989, 'reward_std': 0.011360843479633332, 'frac_reward_zero_std': 0.4, 'entropy': 2.875260353088379, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'epoch': 2.86}
# {'train_runtime': 3460.1248, 'train_samples_per_second': 0.173, 'train_steps_per_second': 0.087, 'train_loss': -2.8818845748901367e-07, 'epoch': 2.86}
# 100%|█████████████████████████████████████████| 300/300 [57:38<00:00, 11.53s/it]
# Saved metrics → evaluation/results/training_metrics.json
# Real training complete → checkpoints/final
# wandb:
# wandb: 🚀 View run final-better-reward at: https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/cccimx7s
# wandb: Find logs at: wandb/run-20260426_073200-cccimx7s/logs

# %%
import json
from pathlib import Path

metrics_path = Path('evaluation/results/training_metrics.json')
metrics = json.loads(metrics_path.read_text())
print('Metrics file:', metrics_path)
print('Mode:', metrics.get('mode'))
print('Model:', metrics.get('model_id'))
print('Train runtime (s):', metrics.get('train_runtime_seconds'))
print('WandB URL:', metrics.get('wandb_run_url'))
print('Loss points:', len(metrics.get('loss_curve', [])))
print('Reward points:', len(metrics.get('reward_curve', [])))
# Out:
# Metrics file: evaluation/results/training_metrics.json
# Mode: real
# Model: Qwen/Qwen2.5-1.5B-Instruct
# Train runtime (s): 3460.1248
# WandB URL: https://wandb.ai/yusufindian09-aaa/meta_hackathon/runs/cccimx7s
# Loss points: 60
# Reward points: 60

# %%
# !python evaluation/evaluate.py --episodes 50
# !python evaluation/plot_results.py
# !ls -lah evaluation/results
# Out:
# Saved evaluation/results/evaluation_summary.json
# Saved PNG plots in evaluation/results/
# total 1.1M
# drwxr-xr-x 2 root root 4.0K Apr 26 07:24 .
# drwxr-xr-x 4 root root 4.0K Apr 26 07:09 ..
# -rw-r--r-- 1 root root  35K Apr 26 08:29 component_breakdown.png
# -rw-r--r-- 1 root root  49K Apr 26 08:29 decision_heatmap.png
# -rw-r--r-- 1 root root  21K Apr 26 08:29 energy_trajectory.png
# -rw-r--r-- 1 root root 6.8K Apr 26 08:29 evaluation_summary.json
# -rw-r--r-- 1 root root  14K Apr 26 08:29 loss_curve.png
# -rw-r--r-- 1 root root 466K Apr 26 07:09 profiling_20260426.png
# -rw-r--r-- 1 root root  51K Apr 26 08:29 reward_curve.png
# -rw-r--r-- 1 root root 348K Apr 26 07:09 train_20260426.png
# -rw-r--r-- 1 root root  58K Apr 26 08:29 training_metrics.json

# %%
# Package submission artifacts for download
# !zip -r submission_artifacts.zip README.md openenv.yaml environment training evaluation/results -x "*/__pycache__/*" "*.pyc" ".ipynb_checkpoints/*"
# !ls -lah submission_artifacts.zip
# Out:
# updating: README.md (deflated 63%)
# updating: openenv.yaml (deflated 29%)
# updating: environment/ (stored 0%)
# updating: environment/consequences.py (deflated 65%)
# updating: environment/judge.py (deflated 55%)
# updating: environment/env.py (deflated 66%)
# updating: environment/__init__.py (deflated 23%)
# updating: environment/events.py (deflated 74%)
# updating: environment/state.py (deflated 66%)
# updating: environment/reward.py (deflated 67%)
# updating: training/ (stored 0%)
# updating: training/rollout.py (deflated 50%)
# updating: training/FINAL.ipynb (deflated 88%)
# updating: training/grpo_config.py (deflated 43%)
# updating: training/train.py (deflated 71%)
# updating: training/push_to_hf.py (deflated 50%)
# updating: training/__init__.py (stored 0%)
# updating: training/train.ipynb (deflated 70%)
# updating: evaluation/results/ (stored 0%)
# updating: evaluation/results/evaluation_summary.json (deflated 81%)
# updating: evaluation/results/profiling_20260426.png (deflated 3%)
# updating: evaluation/results/reward_curve.png (deflated 4%)
# updating: evaluation/results/energy_trajectory.png (deflated 12%)
# updating: evaluation/results/loss_curve.png (deflated 21%)
# updating: evaluation/results/decision_heatmap.png (deflated 12%)
# updating: evaluation/results/training_metrics.json (deflated 91%)
# updating: evaluation/results/train_20260426.png (deflated 6%)
# updating: evaluation/results/component_breakdown.png (deflated 14%)
# -rw-r--r-- 1 root root 972K Apr 26 08:29 submission_artifacts.zip

# %%
# Optional: upload model to HF Model Hub
# Uncomment and edit repo id when needed
# !python training/push_to_hf.py --repo-id YUS200619/meta_hackathon-qwen-model --folder checkpoints/final
# Out:
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
# Processing Files (1 / 1)      :  13%|█▊            | 11.4MB / 85.3MB, 28.5MB/s
#
#
#   ...adapter_model.safetensors:   0%|              | 45.7kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  13%|█▉            | 11.5MB / 85.3MB, 19.1MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   0%|              | 45.7kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   0%|              | 45.7kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  14%|█▉            | 12.0MB / 85.3MB, 10.0MB/s
# New Data Upload               :   1%|              |  553kB / 73.9MB,  461kB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:   1%|              |  599kB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  17%|██▎           | 14.2MB / 85.3MB, 8.89MB/s
# New Data Upload               :   4%|▌             | 2.76MB / 73.9MB, 1.73MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  22%|███           | 18.7MB / 85.3MB, 10.4MB/s
# New Data Upload               :  10%|█▎            | 7.19MB / 73.9MB, 3.99MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  28%|███▉          | 24.2MB / 85.3MB, 12.1MB/s
# New Data Upload               :  17%|██▍           | 12.7MB / 73.9MB, 6.36MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  41%|█████▋        | 34.7MB / 85.3MB, 15.8MB/s
# New Data Upload               :  31%|████▍         | 23.2MB / 73.9MB, 10.6MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  46%|██████▍       | 39.1MB / 85.3MB, 16.3MB/s
# New Data Upload               :  37%|█████▏        | 27.6MB / 73.9MB, 11.5MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  54%|███████▌      | 45.8MB / 85.3MB, 17.6MB/s
# New Data Upload               :  46%|██████▍       | 34.3MB / 73.9MB, 13.2MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  63%|████████▊     | 54.0MB / 85.3MB, 19.3MB/s
# New Data Upload               :  58%|████████      | 42.6MB / 73.9MB, 15.2MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  71%|█████████▉    | 60.7MB / 85.3MB, 20.2MB/s
# New Data Upload               :  67%|█████████▎    | 49.2MB / 73.9MB, 16.4MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  79%|███████████   | 67.3MB / 85.3MB, 21.0MB/s
# New Data Upload               :  76%|██████████▌   | 55.9MB / 73.9MB, 17.5MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  85%|███████████▉  | 72.8MB / 85.3MB, 21.4MB/s
# New Data Upload               :  83%|███████████▋  | 61.4MB / 73.9MB, 18.1MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  92%|████████████▊ | 78.4MB / 85.3MB, 21.8MB/s
# New Data Upload               :  91%|████████████▋ | 66.9MB / 73.9MB, 18.6MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 67.0MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 67.0MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 67.0MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors:  91%|████████████▋ | 67.0MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      :  97%|█████████████▌| 82.5MB / 85.3MB, 17.9MB/s
# New Data Upload               :  96%|█████████████▍| 71.0MB / 73.9MB, 15.4MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (1 / 2)      : 100%|█████████████▉| 85.3MB / 85.3MB, 17.8MB/s
# New Data Upload               : 100%|█████████████▉| 73.8MB / 73.9MB, 15.4MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|█████████████▉| 73.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 85.3MB / 85.3MB, 16.4MB/s
# New Data Upload               : 100%|██████████████| 73.9MB / 73.9MB, 14.2MB/s
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
#   ...adapter_model.safetensors: 100%|██████████████| 73.9MB / 73.9MB
#
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#
#
# Processing Files (2 / 2)      : 100%|██████████████| 85.3MB / 85.3MB, 15.8MB/s
# New Data Upload               : 100%|██████████████| 73.9MB / 73.9MB, 13.7MB/s
#   ...ints/final/tokenizer.json: 100%|██████████████| 11.4MB / 11.4MB
#   ...adapter_model.safetensors: 100%|██████████████| 73.9MB / 73.9MB
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 403, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 500 Server Error: Internal Server Error for url: https://huggingface.co/api/models/YUS200619/meta_hackathon-qwen-model/commit/main
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/kaggle/working/meta_hackathon/training/push_to_hf.py", line 27, in <module>
#     main()
#   File "/kaggle/working/meta_hackathon/training/push_to_hf.py", line 22, in main
#     api.upload_folder(repo_id=args.repo_id, repo_type="model", folder_path=str(folder))
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 1687, in _inner
#     return fn(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 4930, in upload_folder
#     commit_info = self.create_commit(
#                   ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 1687, in _inner
#     return fn(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 4321, in create_commit
#     hf_raise_for_status(commit_resp, endpoint_name="commit")
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 476, in hf_raise_for_status
#     raise _format(HfHubHTTPError, str(e), response) from e
# huggingface_hub.errors.HfHubHTTPError: 500 Server Error: Internal Server Error for url: https://huggingface.co/api/models/YUS200619/meta_hackathon-qwen-model/commit/main (Request ID: Root=1-69edcd03-6bfa55665327839e031ce2ae;4756eee4-cf1f-4d46-92a6-0da29405171d)
#
# Internal Error - We're working hard to fix this as soon as possible!
